# %%
#Vamos fazer um programa para verificar quem é o assassino de um crime. 
#Para descobrir o assassino, a polícia faz um pequeno questionário com 5 
#perguntas onde a resposta só pode ser sim ou não:
#a. Mora perto da vítima?
#b. Já trabalhou com a vítima?
#c. Telefonou para a vítima?
#d. Esteve no local do crime?
#e. Devia para a vítima?
#Cada resposta sim dá um ponto para o suspeito. A polícia considera que os 
#suspeitos com 5 pontos são os assassinos, com 4 a 3 pontos são cúmplices e 
#2 pontos são apenas suspeitos, necessitando outras investigações. Valores 
#iguais ou abaixo de 1 são liberados.

pontos_suspeito = 0
contador_moradia = 0
moradia = input("Você mora perto da Vítima?")
print(moradia)

if moradia == "Sim":
    contador_moradia = contador_moradia + 1
    print('Você pode SER UM SUSPEITO!')
else:
    print('Você pode NÃO SER UM SUSPEITO!')
    
print('Pontos de Suspeito: ',contador_moradia)


contador_trabalho = 0
trabalho = input("Você trabalha perto da Vítima?")
print(trabalho)

if trabalho == "Sim":
    contador_trabalho = contador_trabalho + 1
    print('Você pode SER UM SUSPEITO!')
else:
    print('Você pode NÃO SER UM SUSPEITO!')
    
print('Pontos de Suspeito: ',contador_trabalho)

contador_telefone = 0
telefone = input("Você telefonou para a Vítima?")
print(telefone)

if telefone == "Sim":
    contador_telefone = contador_telefone + 1
    print('Você pode SER UM SUSPEITO!')
else:
    print('Você pode NÃO SER UM SUSPEITO!')
    
print('Pontos de Suspeito: ',contador_telefone)

contador_local = 0
local = input("Você esteve no local do crime?")
print(trabalho)

if local == "Sim":
    contador_local = contador_local + 1
    print('Você pode SER UM SUSPEITO!')
else:
    print('Você pode NÃO SER UM SUSPEITO!')
    
print('Pontos de Suspeito: ',contador_local)

contador_divida = 0
divida = input("Você devia para a Vítima?")
print(divida)

if divida == "Sim":
    contador_divida = contador_divida + 1
    print('Você pode SER UM SUSPEITO!')
else:
    print('Você pode NÃO SER UM SUSPEITO!')
    
print('Pontos de Suspeito: ',contador_divida)

pontos_suspeito = contador_moradia + contador_trabalho + contador_telefone + contador_local + contador_divida
print(pontos_suspeito)

if pontos_suspeito == 5:
    print("VOCÊ É O ASSASINO")
elif pontos_suspeito >= 3:
    print("VOCÊ É UM CUMPLICE")
elif pontos_suspeito == 2:
    print("VOCÊ É APENAS UM SUSPEITO")
else:
    print("VOCÊ SERÁ LIBERADO DA INVESTIGAÇÃO")
# Out:
# Você mora perto da Vítima?Sim
# Sim
# Você pode SER UM SUSPEITO!
# Pontos de Suspeito:  1
# Você trabalha perto da Vítima?Sim
# Sim
# Você pode SER UM SUSPEITO!
# Pontos de Suspeito:  1
# Você telefonou para a Vítima?Sim
# Sim
# Você pode SER UM SUSPEITO!
# Pontos de Suspeito:  1
# Você esteve no local do crime?Sim
# Sim
# Você pode SER UM SUSPEITO!
# Pontos de Suspeito:  1
# Você devia para a Vítima?Sim
# Sim
# Você pode SER UM SUSPEITO!
# Pontos de Suspeito:  1
# 5
# VOCÊ É O ASSASINO
